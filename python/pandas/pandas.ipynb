# %% [markdown]
# # Data analysis with pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Series
#
# Uma Series é como um array unidimensional, uma lista de valores. Toda Series possui um índice, o index,
# que dá rótulos a cada elemento da lista.

# %%
notas = pd.Series([2,5,7,10,6])

notas.values
# Out:
# array([ 2,  5,  7, 10,  6])

# %%
notas.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
notas = pd.Series([2,5,7,6,10], index=['Alfredo', 'Bernardo', 'Raissa', 'Julia', 'Caique'])

notas['Caique']
# Out:
# np.int64(10)

# %%
print('Media', notas.mean())
print('Desvio padrão', notas.std())

# estatiscas basicas
notas.describe()
# Out:
# Media 6.0
# Desvio padrão 2.9154759474226504
# count     5.000000
# mean      6.000000
# std       2.915476
# min       2.000000
# 25%       5.000000
# 50%       6.000000
# 75%       7.000000
# max      10.000000
# dtype: float64

# %%
# series structure works well with numpy 

print(notas**2, '\n')

print(np.log(notas))
# Out:
# Alfredo       4
# Bernardo     25
# Raissa       49
# Julia        36
# Caique      100
# dtype: int64
#
# Alfredo     0.693147
# Bernardo    1.609438
# Raissa      1.945910
# Julia       1.791759
# Caique      2.302585
# dtype: float64

# %% [markdown]
# ## Dataframe
#
# DataFrame é uma estrutura bidimensional de dados, como uma planilha. Os tipos de dados que com-
# poem as colunas podem ser verificados por um metodo proprio, conforme obtemos no codigo fonte
# "DataFrame".

# %%
df = pd.DataFrame({
    'Aluno': ['Alfredo', 'Bernardo', 'Raissa', 'Julia', 'Caique'],
    'Faltas': [0,2,8,6,5],
    'Prova': [10,7,8,9,8.5],
    'Seminário': [9.5,9.5,8.5,9.0,9.0],
})

df
# Out:
#       Aluno  Faltas  Prova  Seminário
# 0   Alfredo       0   10.0        9.5
# 1  Bernardo       2    7.0        9.5
# 2    Raissa       8    8.0        8.5
# 3     Julia       6    9.0        9.0
# 4    Caique       5    8.5        9.0

# %%
print(df.dtypes, '\n')
print(df.columns, '\n')
df['Seminário']
# Out:
# Aluno         object
# Faltas         int64
# Prova        float64
# Seminário    float64
# dtype: object
#
# Index(['Aluno', 'Faltas', 'Prova', 'Seminário'], dtype='object')
# 0    9.5
# 1    9.5
# 2    8.5
# 3    9.0
# 4    9.0
# Name: Seminário, dtype: float64

# %%
df.describe()
# Out:
#          Faltas      Prova  Seminário
# count  5.000000   5.000000    5.00000
# mean   4.200000   8.500000    9.10000
# std    3.193744   1.118034    0.41833
# min    0.000000   7.000000    8.50000
# 25%    2.000000   8.000000    9.00000
# 50%    5.000000   8.500000    9.00000
# 75%    6.000000   9.000000    9.50000
# max    8.000000  10.000000    9.50000

# %%
print(df.sort_values(by=['Seminário', 'Faltas']), '\n')

print(df.sort_values(by=['Seminário', 'Faltas'], ascending=False), '\n')
# sort values does not affect original dataframe
print(df)
# Out:
#       Aluno  Faltas  Prova  Seminário
# 2    Raissa       8    8.0        8.5
# 4    Caique       5    8.5        9.0
# 3     Julia       6    9.0        9.0
# 0   Alfredo       0   10.0        9.5
# 1  Bernardo       2    7.0        9.5
#
#       Aluno  Faltas  Prova  Seminário
# 1  Bernardo       2    7.0        9.5
# 0   Alfredo       0   10.0        9.5
# 3     Julia       6    9.0        9.0
# 4    Caique       5    8.5        9.0
# 2    Raissa       8    8.0        8.5
#
#       Aluno  Faltas  Prova  Seminário
# 0   Alfredo       0   10.0        9.5
# 1  Bernardo       2    7.0        9.5
# 2    Raissa       8    8.0        8.5
# 3     Julia       6    9.0        9.0
# 4    Caique       5    8.5        9.0

# %%
print(df.loc[0], '\n')

print(df[df['Aluno'] == 'Alfredo'], '\n')

print(df[df['Prova'] > 7], '\n')

print(df[(df['Prova'] > 7) & (df['Seminário'] > 9.0)], '\n')
# Out:
# Aluno        Alfredo
# Faltas             0
# Prova           10.0
# Seminário        9.5
# Name: 0, dtype: object
#
#      Aluno  Faltas  Prova  Seminário
# 0  Alfredo       0   10.0        9.5
#
#      Aluno  Faltas  Prova  Seminário
# 0  Alfredo       0   10.0        9.5
# 2   Raissa       8    8.0        8.5
# 3    Julia       6    9.0        9.0
# 4   Caique       5    8.5        9.0
#
#      Aluno  Faltas  Prova  Seminário
# 0  Alfredo       0   10.0        9.5

# %% [markdown]
# ## Read and manipulate files

# %%
df = pd.read_csv('assets/dados_v3.csv')

df
# Out:
#       condominio  quartos  suites  vagas  area      bairro    preco       pm2
# 0            350        1     0.0    1.0    21  Campo Belo   340000  16190.48
# 1            800        1     0.0    1.0    64  Campo Belo   770000  12031.25
# 2            674        1     0.0    1.0    61  Campo Belo   600000   9836.07
# 3            700        1     1.0    1.0    70  Campo Belo   700000  10000.00
# 4            440        1     0.0    1.0    44  Campo Belo   515000  11704.55
# ...          ...      ...     ...    ...   ...         ...      ...       ...
# 1992        1080        3     1.0    1.0    80   Alphavile   680000   8500.00
# 1993         750        3     0.0    1.0    82   Alphavile   650000   7926.83
# 1994         700        3     1.0    1.0   100   Alphavile   629900   6299.00
# 1995        1850        3     1.0    2.0   166   Alphavile  1600000   9638.55
# 1996         800        3     1.0    1.0   107   Alphavile   540000   5046.73
#
# [1997 rows x 8 columns]

# %%
#get unique data
print(df.bairro.unique(), '\n')

# count values
print(df.bairro.value_counts(), '\n')
# count % values
print(df.bairro.value_counts(normalize=True), '\n')
# Out:
# ['Campo Belo' 'Itaim' 'Moema' 'Tatuapé' 'Jardins' 'Jardim Europa'
#  'Alphavile']
#
# bairro
# Itaim            346
# Alphavile        341
# Campo Belo       307
# Jardins          281
# Jardim Europa    280
# Tatuapé          237
# Moema            205
# Name: count, dtype: int64
#
# bairro
# Itaim            0.173260
# Alphavile        0.170756
# Campo Belo       0.153731
# Jardins          0.140711
# Jardim Europa    0.140210
# Tatuapé          0.118678
# Moema            0.102654
# Name: proportion, dtype: float64

# %%
df.groupby('bairro').mean()
# Out:
#                 condominio   quartos    suites     vagas        area  \
# bairro
# Alphavile       681.175953  2.131965  0.944282  1.143695   81.457478
# Campo Belo      914.475570  2.107492  1.048860  1.159609   83.837134
# Itaim           991.861272  2.101156  1.034682  1.080925  101.855491
# Jardim Europa  1260.010714  2.207143  1.064286  1.164286   91.832143
# Jardins        1357.120996  2.181495  1.192171  1.220641  100.615658
# Moema           985.234146  2.058537  1.029268  1.200000   88.497561
# Tatuapé         619.940928  2.097046  0.970464  1.130802   79.949367
#
#                       preco           pm2
# bairro
# Alphavile      5.750780e+05   7149.804985
# Campo Belo     1.010614e+06  12034.486189
# Itaim          1.216344e+06  11965.298699
# Jardim Europa  1.946193e+06  20761.351036
# Jardins        2.033096e+06  19738.407794
# Moema          1.454571e+06  16511.582780
# Tatuapé        4.788869e+05   6145.624473

# %%
df.groupby('bairro').mean() ['area'].sort_values()
# Out:
# bairro
# Tatuapé           79.949367
# Alphavile         81.457478
# Campo Belo        83.837134
# Moema             88.497561
# Jardim Europa     91.832143
# Jardins          100.615658
# Itaim            101.855491
# Name: area, dtype: float64

# %%
print(df["bairro"].apply(lambda x: x[:4]), '\n')
df['bairro'].apply(lambda x: x.upper())
# Out:
# 0       Camp
# 1       Camp
# 2       Camp
# 3       Camp
# 4       Camp
#         ...
# 1992    Alph
# 1993    Alph
# 1994    Alph
# 1995    Alph
# 1996    Alph
# Name: bairro, Length: 1997, dtype: object
# 0       CAMPO BELO
# 1       CAMPO BELO
# 2       CAMPO BELO
# 3       CAMPO BELO
# 4       CAMPO BELO
#            ...
# 1992     ALPHAVILE
# 1993     ALPHAVILE
# 1994     ALPHAVILE
# 1995     ALPHAVILE
# 1996     ALPHAVILE
# Name: bairro, Length: 1997, dtype: object

# %%
df2 = df.head()
df2 = df2.replace({"pm2": {12031.25: np.nan}})
df2
# Out:
#    condominio  quartos  suites  vagas  area      bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Campo Belo  340000  16190.48
# 1         800        1     0.0    1.0    64  Campo Belo  770000       NaN
# 2         674        1     0.0    1.0    61  Campo Belo  600000   9836.07
# 3         700        1     1.0    1.0    70  Campo Belo  700000  10000.00
# 4         440        1     0.0    1.0    44  Campo Belo  515000  11704.55

# %%
#  drop na lines
df2.dropna()
# Out:
#    condominio  quartos  suites  vagas  area      bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Campo Belo  340000  16190.48
# 2         674        1     0.0    1.0    61  Campo Belo  600000   9836.07
# 3         700        1     1.0    1.0    70  Campo Belo  700000  10000.00
# 4         440        1     0.0    1.0    44  Campo Belo  515000  11704.55

# %%
df2.fillna(9000)
# TODO: see how to get mean of value
# Out:
#    condominio  quartos  suites  vagas  area      bairro   preco       pm2
# 0         350        1     0.0    1.0    21  Campo Belo  340000  16190.48
# 1         800        1     0.0    1.0    64  Campo Belo  770000   9000.00
# 2         674        1     0.0    1.0    61  Campo Belo  600000   9836.07
# 3         700        1     1.0    1.0    70  Campo Belo  700000  10000.00
# 4         440        1     0.0    1.0    44  Campo Belo  515000  11704.55

# %%
df2.isna()
# Out:
#    condominio  quartos  suites  vagas   area  bairro  preco    pm2
# 0       False    False   False  False  False   False  False  False
# 1       False    False   False  False  False   False  False   True
# 2       False    False   False  False  False   False  False  False
# 3       False    False   False  False  False   False  False  False
# 4       False    False   False  False  False   False  False  False

# %% [markdown]
# ## Advanced Dataframes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import Image

pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### Joining
#
# A partir do docstring:
#
# how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#
# · left: usa apenas chaves do frame da esquerda (SQL: left outer join).
#
# . right: usa apenas chaves do frame da direita (SQL: right outer join).
#
# . outer: usa a unio das chaves de ambos os frames (SQL: full outer join).
#
# · inner: usa a interseção das chaves de ambos os frames (SQL: inner join).

# %%
left_frame = pd.DataFrame({'key': range(5),'left_value': ['a','b','c','d','e']})
right_frame = pd.DataFrame({'key': range(2, 7),'right_value': ['f','g','h','i','j']})
print(left_frame)
print('\n')
print(right_frame)
# Out:
#    key left_value
# 0    0          a
# 1    1          b
# 2    2          c
# 3    3          d
# 4    4          e
#
#
#    key right_value
# 0    2           f
# 1    3           g
# 2    4           h
# 3    5           i
# 4    6           j

# %% [markdown]
# #### Inner join

# %%
pd.merge(left_frame, right_frame, on='key', how='inner')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h

# %%
# the above code is just like sql inner join, if we want all values based on a left/right key or index we can do it

pd.merge(left_frame, right_frame, left_on='key', right_index=True)
# Out:
#    key  key_x left_value  key_y right_value
# 0    0      0          a      2           f
# 1    1      1          b      3           g
# 2    2      2          c      4           h
# 3    3      3          d      5           i
# 4    4      4          e      6           j

# %% [markdown]
# #### Left join

# %%
pd.merge(left_frame, right_frame, on='key', how='left')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h

# %% [markdown]
# #### Right join

# %%
pd.merge(left_frame, right_frame, on='key', how='right')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h
# 3    5        NaN           i
# 4    6        NaN           j

# %% [markdown]
# ### Outer join

# %%
pd.merge(left_frame, right_frame, on='key', how='outer')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h
# 5    5        NaN           i
# 6    6        NaN           j

# %% [markdown]
# ### Combining
#
# Pandas também provê mecanismos de combinar DataFrames a partir do eixo - pandas.concat. Essa função é equivalente ao SQL UNION, mas, logicamente, há muito mais que se pode fazer com ela.
#
# Pandas.concat pega uma lista de series ou DataFrames e retorna uma Series ou DataFrame de objetos concatenados. Perceba que, por causa dessa função, você pode combinar vários objetos em um.

# %%
pd.concat([left_frame, right_frame])
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c         NaN
# 3    3          d         NaN
# 4    4          e         NaN
# 0    2        NaN           f
# 1    3        NaN           g
# 2    4        NaN           h
# 3    5        NaN           i
# 4    6        NaN           j

# %%
pd.concat([left_frame, right_frame], axis=1)
# Out:
#    key left_value  key right_value
# 0    0          a    2           f
# 1    1          b    3           g
# 2    2          c    4           h
# 3    3          d    5           i
# 4    4          e    6           j

# %% [markdown]
# ### Grouping

# %%
recife_df = pd.read_csv('assets/salarios_recife_outubro_2013.csv', converters={'R$SALARIO' : lambda x: float(x.replace('R$', ''))})

recife_df
# Out:
#                                                     ORGAO  \
# 0                                  SECRETARIA DE EDUCACAO
# 1                                  SECRETARIA DE EDUCACAO
# 2                                  SECRETARIA DE EDUCACAO
# 3         SERES - SECRETARIA EXECUTIVA DE RESSOCIALIZACAO
# 4                                  SECRETARIA DE EDUCACAO
# ...                                                   ...
# 133907  ITERPE - INSTITUTO DE TERRAS E REFORMA AGRARIA...
# 133908  ITERPE - INSTITUTO DE TERRAS E REFORMA AGRARIA...
# 133909  ITERPE - INSTITUTO DE TERRAS E REFORMA AGRARIA...
# 133910  ITERPE - INSTITUTO DE TERRAS E REFORMA AGRARIA...
# 133911  ITERPE - INSTITUTO DE TERRAS E REFORMA AGRARIA...
#
#                                                      NOME  \
# 0                                                 9/16/13
# 1       GOV. PERNAMBUCO    ****      CONSISTHR      **...
# 2                                 ARNEY SPINELI GUIMARAES
# 3                                 ARNEY SPINELI GUIMARAES
# 4                          ITA DE CASSIA FISCHER DEL PINO
# ...                                                   ...
# 133907                    SIMONE VALERIA DE GUSMAO SANTOS
# 133908                               THAIS SOARES FONSECA
# 133909                   VIVIANE DA SILVA LUCENA PATRIOTA
# 133910                           WAGNER LEITE DE OLIVEIRA
# 133911                     WANDERSON SIQUEIRA FREIRE LINS
#
#                                CATEGORIA                          CARGO  \
# 0                            ESTATUTARIO            TECNICO EDUCACIONAL
# 1                            ESTATUTARIO    ASSIST ADMINIST EDUCACIONAL
# 2                            ESTATUTARIO            TECNICO EDUCACIONAL
# 3       CTD - CONTRATO TEMPO DETERMINADO                PSICOLOGO - CTD
# 4                            ESTATUTARIO                      PROFESSOR
# ...                                  ...                            ...
# 133907  CTD - CONTRATO TEMPO DETERMINADO  ASSISTENTE ADMINISTRATIVO CTD
# 133908                      COMISSIONADO  ASSESS SUP AO SEC-ASS NAT TEC
# 133909  CTD - CONTRATO TEMPO DETERMINADO   TECNICO NA AREA SOCIAL - CTD
# 133910  CTD - CONTRATO TEMPO DETERMINADO         TECNICO AGRICOLA - CTD
# 133911  CTD - CONTRATO TEMPO DETERMINADO      ENGENHEIRO AGRONOMO - CTD
#
#                                FUNCAO  R$SALARIO
# 0                                 NaN    1902.24
# 1                                 NaN    2667.97
# 2                                 NaN    2302.24
# 3                                 NaN    1770.00
# 4                                 NaN    2325.26
# ...                               ...        ...
# 133907                            NaN    1100.00
# 133908  ASSESS SUP AO SEC-ASS NAT TEC    4429.61
# 133909                            NaN    2200.00
# 133910                            NaN    1635.00
# 133911                            NaN    4590.00
#
# [133912 rows x 6 columns]

# %%
orgao = recife_df.groupby('ORGAO')
orgao.count()
# Out:
#                                                     NOME  CATEGORIA  CARGO  \
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND...   280        280    280
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ...   143        143    143
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA           467        467    467
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA          97         97     97
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO    84         84     84
# ...                                                  ...        ...    ...
# SECRETARIA DO GOVERNO                                 53         53     53
# SECRETARIA DOS ESPORTES                               41         41     41
# SECRETARIA EXTRAORDINARIA DA COPA DE 2014             41         41     41
# SERES - SECRETARIA EXECUTIVA DE RESSOCIALIZACAO     2049       2049   2049
# UPE - UNIVERSIDADE DE PERNAMBUCO                    5115       5115   5115
#
#                                                     FUNCAO  R$SALARIO
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND...     103        280
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ...     104        143
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA              58        467
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA            92         97
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO      77         84
# ...                                                    ...        ...
# SECRETARIA DO GOVERNO                                   52         53
# SECRETARIA DOS ESPORTES                                 40         41
# SECRETARIA EXTRAORDINARIA DA COPA DE 2014               38         41
# SERES - SECRETARIA EXECUTIVA DE RESSOCIALIZACAO        583       2049
# UPE - UNIVERSIDADE DE PERNAMBUCO                      3312       5115
#
# [61 rows x 5 columns]

# %%
orgao['R$SALARIO'].sum() [5:10]
# Out:
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO                             2931535.84
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS                                 530249.65
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO                                          413150.11
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAMENTO E PESQUISA DE PERNAMBUCO     256889.50
# CONSERVATORIO PERNAMBUCANO DE MUSICA                                            232381.19
# Name: R$SALARIO, dtype: float64

# %%
orgao['CARGO'].apply(lambda x: len(x.unique())).sort_values(ascending=False)
# Out:
# ORGAO
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA                                     108
# SECRETARIA DE SAUDE                                                             65
# SECRETARIA DE EDUCACAO                                                          64
# HEMOPE - FUNDACAO DE HEMATOLOGIA E HEMOTERAPIA DE PERNAMBUCO                    62
# UPE - UNIVERSIDADE DE PERNAMBUCO                                                49
#                                                                               ...
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAMENTO E PESQUISA DE PERNAMBUCO      8
# SECRETARIA EXTRAORDINARIA DA COPA DE 2014                                        8
# IRH - INSTITUTO DE RECURSOS HUMANOS                                              4
# PENSOES ESPECIAIS                                                                3
# PEN ESP DEC JUD                                                                  1
# Name: CARGO, Length: 61, dtype: int64

# %%
def ranker(df):
    ''' 
    Atribui uma classificação a cada funcionário com base no salário, sendo 1 o mais bem pago. 
Assume que os dados estão classificados com DESC.
    '''
    df['orgao_rank'] = np.arange(len(df)) + 1
    return df

# %%
recife_df.sort_values('R$SALARIO', ascending=False, inplace=True)
recife_df = recife_df.groupby('ORGAO').apply(ranker)
recife_df[recife_df.orgao_rank == 1].head(10)
# Out:
# /tmp/ipykernel_33551/1020714441.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   recife_df = recife_df.groupby('ORGAO').apply(ranker)
#                                                                                                        ORGAO  \
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND... 8898     SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEN...
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ... 119220  AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO...
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA         116427         ADMINISTRACAO GERAL DE FERNANDO DE NORONHA
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA       133702       APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO 116531  ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAM...
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318   ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORM...
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS    132105    CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO             91898              CEPE - COMPANHIA EDITORA DA PERNAMBUCO
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAME... 116676  CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAM...
# CONSERVATORIO PERNAMBUCANO DE MUSICA               82736                CONSERVATORIO PERNAMBUCANO DE MUSICA
#
#                                                                                                 NOME  \
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND... 8898            ANTONIO CARLOS MARANHAO DE AGUIAR
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ... 119220            ROBERTO DE ABREU E LIMA ALMEIDA
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA         116427                       ROMEU NEVES BAPTISTA
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA       133702                       MARCELO CAUAS ASFORA
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO 116531          FLAVIO CAVALCANTI VELOSO DA COSTA
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318                 ADEMILTON CIPRIANO DA SILVA
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS    132105                   ADILSON SOARES RODRIGUES
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO             91898   LUIZ NAPOLEAO VIEIRA DE MEDEIROS SOBRINHO
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAME... 116676                    MAURILIO SOARES DE LIMA
# CONSERVATORIO PERNAMBUCANO DE MUSICA               82736                                 SIDOR HULAK
#
#                                                               CATEGORIA  \
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND... 8898    COMISSIONADO
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ... 119220  COMISSIONADO
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA         116427  COMISSIONADO
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA       133702  COMISSIONADO
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO 116531   CONSELHEIRO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318      CELETISTA
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS    132105  COMISSIONADO
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO             91898   EXTRA QUADRO
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAME... 116676  COMISSIONADO
# CONSERVATORIO PERNAMBUCANO DE MUSICA               82736    ESTATUTARIO
#
#                                                                                     CARGO  \
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND... 8898              SECRETARIO DE ESTADO
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ... 119220  DIRETOR PRESIDENTE       CDA-1
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA         116427            ADM.GER.F.DE NORONHA
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA       133702                    EXTRA QUADRO
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO 116531           SERVIDOR EXTRA-QUADRO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318     AM EM GEST TEC INF E COM-SUP
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS    132105                   GERENTE DAS-4
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO             91898         SUPERINTENDENTE JURIDICO
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAME... 116676           SERVIDOR EXTRA-QUADRO
# CONSERVATORIO PERNAMBUCANO DE MUSICA               82736          PROFESSOR NIVEL TECNICO
#
#                                                                                    FUNCAO  \
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND... 8898                               NaN
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ... 119220  DIRETOR PRESIDENTE       CDA-1
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA         116427            ADM.GER.F.DE NORONHA
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA       133702              DIRETOR PRESIDENTE
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO 116531                     CONSELHEIRO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318                              NaN
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS    132105                   GERENTE DAS-4
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO             91898         SUPERINTENDENTE JURIDICO
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAME... 116676              DIRETOR PRESIDENTE
# CONSERVATORIO PERNAMBUCANO DE MUSICA               82736    GER E ASSESSORAMENTO SUPERIOR
#
#                                                            R$SALARIO  \
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND... 8898     10570.00
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ... 119220   12757.28
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA         116427    9966.62
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA       133702    7973.30
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO 116531   10963.28
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318    28953.55
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS    132105   13178.08
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO             91898    10926.36
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAME... 116676    7973.30
# CONSERVATORIO PERNAMBUCANO DE MUSICA               82736     8094.69
#
#                                                            orgao_rank
# ORGAO
#  SECRETARIA DE TRABALHO,QUALIFICACAO E EMPREEND... 8898             1
# AD DIPER -AGENCIA DE DESENVOLVIMENTO ECONOMICO ... 119220           1
# ADMINISTRACAO GERAL DE FERNANDO DE NORONHA         116427           1
# APAC - AGENCIA PERNAMBUCANA DE AGUAS E CLIMA       133702           1
# ARPE - AGENCIA ESTADUAL DE REGULACAO DE PERNAMBUCO 116531           1
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318            1
# CEHAB - COMPANHIA ESTADUAL DE HABITACAO E OBRAS    132105           1
# CEPE - COMPANHIA EDITORA DA PERNAMBUCO             91898            1
# CONDEPE / FIDEM - AGENCIA ESTADUAL DE PLANEJAME... 116676           1
# CONSERVATORIO PERNAMBUCANO DE MUSICA               82736            1

# %%
recife_df[recife_df.ORGAO == "ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO"] [:5]
# Out:
#                                                                                                       ORGAO  \
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318  ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORM...
#                                                    91487  ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORM...
#                                                    91373  ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORM...
#                                                    91737  ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORM...
#                                                    91457  ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORM...
#
#                                                                                     NOME  \
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318     ADEMILTON CIPRIANO DA SILVA
#                                                    91487      GISELE MARIA DE SOUZA LIMA
#                                                    91373           AURELIO GABRIELE NETO
#                                                    91737  ROBERTO DO REGO BARROS CARICIO
#                                                    91457         FABIO BARROS DA FONSECA
#
#                                                           CATEGORIA  \
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318  CELETISTA
#                                                    91487  CELETISTA
#                                                    91373  CELETISTA
#                                                    91737  CELETISTA
#                                                    91457  CELETISTA
#
#                                                                                   CARGO  \
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318   AM EM GEST TEC INF E COM-SUP
#                                                    91487   AM EM GEST TEC INF E COM-SUP
#                                                    91373   AM EM GEST TEC INF E COM-SUP
#                                                    91737   AM EM GEST TEC INF E COM-SUP
#                                                    91457  ASS EM GEST TEC INF E COM-SUP
#
#                                                                                  FUNCAO  \
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318                            NaN
#                                                    91487  GERENTE DO REL DO GOV DIGITAL
#                                                    91373               CHEFE DE UNIDADE
#                                                    91737                            NaN
#                                                    91457                            NaN
#
#                                                           R$SALARIO  \
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318   28953.55
#                                                    91487   26840.84
#                                                    91373   19776.35
#                                                    91737   19390.87
#                                                    91457   17614.35
#
#                                                           orgao_rank
# ORGAO
# ATI - AGENCIA ESTADUAL DE TECNOLOGIA DA INFORMACAO 91318           1
#                                                    91487           2
#                                                    91373           3
#                                                    91737           4
#                                                    91457           5
